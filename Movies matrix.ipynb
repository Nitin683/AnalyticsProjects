# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df = pd.read_csv(r'C:\Users\hp\Downloads\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {:.2f}%'.format(col,pct_missing))
# Out:
# name - 0.00%
# rating - 0.00%
# genre - 0.00%
# year - 0.00%
# released - 0.00%
# score - 0.00%
# votes - 0.00%
# director - 0.00%
# writer - 0.00%
# star - 0.00%
# country - 0.00%
# budget - 0.00%
# gross - 0.00%
# company - 0.00%
# runtime - 0.00%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes         int64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5431                               Bad Boys for Life          R     Action
# 5432                              Sonic the Hedgehog         PG     Action
# 5433                                        Dolittle         PG  Adventure
# 5434                            The Call of the Wild         PG  Adventure
# 5435                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5431  2020   January 17, 2020 (United States)    6.6   140000
# 5432  2020  February 14, 2020 (United States)    6.5   102000
# 5433  2020   January 17, 2020 (United States)    5.6    53000
# 5434  2020  February 21, 2020 (United States)    6.8    42000
# 5435  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5431     Adil El Arbi              Peter Craig         Will Smith
# 5432      Jeff Fowler                Pat Casey       Ben Schwartz
# 5433   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5434    Chris Sanders            Michael Green      Harrison Ford
# 5435          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5431   United States   90000000  426505244
# 5432   United States   85000000  319715683
# 5433   United States  175000000  245487753
# 5434          Canada  135000000  111105497
# 5435           China   80000000  461421559
#
#                                   company  runtime
# 0                            Warner Bros.    146.0
# 1                       Columbia Pictures    104.0
# 2                               Lucasfilm    124.0
# 3                      Paramount Pictures     88.0
# 4                          Orion Pictures     98.0
# ...                                   ...      ...
# 5431                    Columbia Pictures    124.0
# 5432                   Paramount Pictures     99.0
# 5433                   Universal Pictures    101.0
# 5434                 20th Century Studios    100.0
# 5435  Beijing Diqi Yinxiang Entertainment    149.0
#
# [5436 rows x 15 columns]

# %%
df['year_corrected'] = df['released'].astype(str).str.split().str[2].str.strip(',')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5431                               Bad Boys for Life          R     Action
# 5432                              Sonic the Hedgehog         PG     Action
# 5433                                        Dolittle         PG  Adventure
# 5434                            The Call of the Wild         PG  Adventure
# 5435                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# 0     1980      June 13, 1980 (United States)    8.4   927000
# 1     1980       July 2, 1980 (United States)    5.8    65000
# 2     1980      June 20, 1980 (United States)    8.7  1200000
# 3     1980       July 2, 1980 (United States)    7.7   221000
# 4     1980      July 25, 1980 (United States)    7.3   108000
# ...    ...                                ...    ...      ...
# 5431  2020   January 17, 2020 (United States)    6.6   140000
# 5432  2020  February 14, 2020 (United States)    6.5   102000
# 5433  2020   January 17, 2020 (United States)    5.6    53000
# 5434  2020  February 21, 2020 (United States)    6.8    42000
# 5435  2020    August 28, 2020 (United States)    6.8     3700
#
#              director                   writer               star  \
# 0     Stanley Kubrick             Stephen King     Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole     Brooke Shields
# 2      Irvin Kershner           Leigh Brackett        Mark Hamill
# 3        Jim Abrahams             Jim Abrahams        Robert Hays
# 4        Harold Ramis       Brian Doyle-Murray        Chevy Chase
# ...               ...                      ...                ...
# 5431     Adil El Arbi              Peter Craig         Will Smith
# 5432      Jeff Fowler                Pat Casey       Ben Schwartz
# 5433   Stephen Gaghan           Stephen Gaghan  Robert Downey Jr.
# 5434    Chris Sanders            Michael Green      Harrison Ford
# 5435          Hu Guan                  Hu Guan    Zhi-zhong Huang
#
#              country     budget      gross  \
# 0     United Kingdom   19000000   46998772
# 1      United States    4500000   58853106
# 2      United States   18000000  538375067
# 3      United States    3500000   83453539
# 4      United States    6000000   39846344
# ...              ...        ...        ...
# 5431   United States   90000000  426505244
# 5432   United States   85000000  319715683
# 5433   United States  175000000  245487753
# 5434          Canada  135000000  111105497
# 5435           China   80000000  461421559
#
#                                   company  runtime year_corrected
# 0                            Warner Bros.    146.0           1980
# 1                       Columbia Pictures    104.0           1980
# 2                               Lucasfilm    124.0           1980
# 3                      Paramount Pictures     88.0           1980
# 4                          Orion Pictures     98.0           1980
# ...                                   ...      ...            ...
# 5431                    Columbia Pictures    124.0           2020
# 5432                   Paramount Pictures     99.0           2020
# 5433                   Universal Pictures    101.0           2020
# 5434                 20th Century Studios    100.0           2020
# 5435  Beijing Diqi Yinxiang Entertainment    149.0           2020
#
# [5436 rows x 16 columns]

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 3743                                      Avatar      PG-13  Action  2009
# 5316                           Avengers: Endgame      PG-13  Action  2019
# 1802                                     Titanic      PG-13   Drama  1997
# 4743  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 5172                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 1385                  Philadelphia Experiment II      PG-13  Action  1993
# 2295                                Ginger Snaps  Not Rated   Drama  2000
# 154                                     Parasite          R  Horror  1982
# 1379                                    Madadayo        NaN   Drama  1993
# 1928                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes          director  \
# 3743  December 18, 2009 (United States)    7.8  1100000     James Cameron
# 5316     April 26, 2019 (United States)    8.4   903000     Anthony Russo
# 1802  December 19, 1997 (United States)    7.8  1100000     James Cameron
# 4743  December 18, 2015 (United States)    7.8   876000       J.J. Abrams
# 5172     April 27, 2018 (United States)    8.4   897000     Anthony Russo
# ...                                 ...    ...      ...               ...
# 1385         June 4, 1994 (South Korea)    4.5     1900  Stephen Cornwell
# 2295              May 11, 2001 (Canada)    6.8    43000      John Fawcett
# 154      March 12, 1982 (United States)    3.9     2300      Charles Band
# 1379             April 17, 1993 (Japan)    7.3     5100    Akira Kurosawa
# 1928           October 1, 1997 (Brazil)    5.7     5800      George Huang
#
#                   writer               star        country     budget  \
# 3743       James Cameron    Sam Worthington  United States  237000000
# 5316  Christopher Markus  Robert Downey Jr.  United States  356000000
# 1802       James Cameron  Leonardo DiCaprio  United States  200000000
# 4743     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 5172  Christopher Markus  Robert Downey Jr.  United States  321000000
# ...                  ...                ...            ...        ...
# 1385  Wallace C. Bennett       Brad Johnson  United States    5000000
# 2295        Karen Walton      Emily Perkins         Canada    5000000
# 154        Alan J. Adler    Robert Glaudini  United States     800000
# 1379        Ishirô Honda   Tatsuo Matsumura          Japan   11900000
# 1928           Andy Burg       Will Friedle  United States   15000000
#
#            gross                         company  runtime year_corrected
# 3743  2847246203           Twentieth Century Fox    162.0           2009
# 5316  2797501328                  Marvel Studios    181.0           2019
# 1802  2201647264           Twentieth Century Fox    194.0           1997
# 4743  2069521700                       Lucasfilm    138.0           2015
# 5172  2048359754                  Marvel Studios    149.0           2018
# ...          ...                             ...      ...            ...
# 1385        2970                Trimark Pictures     97.0           1994
# 2295        2554       Copperheart Entertainment    108.0           2001
# 154         2270                Embassy Pictures     85.0           1982
# 1379         596  DENTSU Music And Entertainment    134.0           1993
# 1928         309                        Daybreak     85.0           1997
#
# [5436 rows x 16 columns]

# %%
plt.scatter(x= df['budget'], y= df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Revenue')
plt.show()

# %%
sns.regplot(x='budget',y='gross',data= df,line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method= 'pearson')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19296\4096930676.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method= 'pearson')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055174  0.205758  0.327781  0.274264  0.074203
# score    0.055174  1.000000  0.473809  0.071792  0.222143  0.414580
# votes    0.205758  0.473809  1.000000  0.440021  0.614904  0.352437
# budget   0.327781  0.071792  0.440021  1.000000  0.740395  0.318595
# gross    0.274264  0.222143  0.614904  0.740395  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
corr_matrix = df.corr(method= 'pearson') 
sns.heatmap(corr_matrix,annot= True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19296\1356942469.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr(method= 'pearson')

# %%
df=df.sort_values(by=['gross'],inplace=False,ascending=False)
df.dtypes
# Out:
# name              category
# rating                int8
# genre                 int8
# year                 int64
# released             int16
# score              float64
# votes                int64
# director             int16
# writer               int16
# star                 int16
# country               int8
# budget               int64
# gross                int64
# company              int16
# runtime            float64
# year_corrected        int8
# dtype: object

# %%
df_num = df

for col in df_num.columns:
    if(df_num[col].dtype=='object'):
        df_num[col] = df_num[col].astype('category')
        df_num[col] = df_num[col].cat.codes
    elif(df_num[col].dtype=='category'):
        df_num[col] = df_num[col].cat.codes   

df_num
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 3743   387       5      0  2009       528    7.8  1100000       787    1265
# 5316   389       5      0  2019       138    8.4   903000       106     515
# 1802  4923       5      6  1997       535    7.8  1100000       787    1265
# 4743  3656       5      0  2015       530    7.8   876000       770    1810
# 5172   390       5      0  2018       146    8.4   897000       106     515
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 1385  2981       5      0  1993      1471    4.5     1900      1810    3112
# 2295  1599       3      6  2000      1726    6.8    43000       954    1687
# 154   2921       6      9  1982      1530    3.9     2300       263      55
# 1379  2401      -1      6  1993        64    7.3     5100        23    1220
# 1928  4980       5      4  1997      2158    5.7     5800       653     161
#
#       star  country     budget       gross  company  runtime  year_corrected
# 3743  1538       47  237000000  2847246203     1388    162.0              31
# 5316  1474       47  356000000  2797501328      987    181.0              41
# 1802  1076       47  200000000  2201647264     1388    194.0              19
# 4743   357       47  245000000  2069521700      949    138.0              37
# 5172  1474       47  321000000  2048359754      987    149.0              40
# ...    ...      ...        ...         ...      ...      ...             ...
# 1385   187       47    5000000        2970     1382     97.0              16
# 2295   528        6    5000000        2554      468    108.0              23
# 154   1477       47     800000        2270      584     85.0               4
# 1379  1687       26   11900000         596      492    134.0              15
# 1928  1818       47   15000000         309      506     85.0              19
#
# [5436 rows x 16 columns]

# %%
corr_matrix = df_num.corr(method= 'pearson') 
sns.heatmap(corr_matrix,annot= True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()
